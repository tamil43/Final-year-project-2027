# %%
import pandas as pd
import numpy as np
import joblib

# %%
df = pd.read_csv(r"D:\Final Year Project 2027\Electricity Demand and Supply Forecasting\Datasets_For_Model_Training\Final_Merged_Dataset.csv")
df.head()
# Out:
#          Date  Electricity_Requirement  Humidity    Rainfall  \
# 0  01-04-2015                   8361.0     70.07  130.566857
# 1  01-05-2015                   8381.0     77.22  160.792286
# 2  01-06-2015                   8302.0     77.55   98.240286
# 3  01-07-2015                   8953.0     73.18   37.804286
# 4  01-08-2015                   8535.0     72.58   63.944286
#
#    Solar_Irradiance      Coal  Oil & Gas  Nuclear     Hydro   Solar     Wind  \
# 0            166.53  70195.44    3246.28  3506.10   9421.19  512.31  1832.30
# 1            155.03  75339.79    3242.43  3457.01  12854.80  560.91  2673.76
# 2            160.31  69044.77    3796.41  3449.28  12509.46  515.11  3946.56
# 3            166.41  70322.24    3662.57  3022.21  15094.48  455.52  6591.88
# 4            167.12  69569.23    3854.07  2834.19  17779.11  510.73  5113.45
#
#    Small-Hydro  Bio Power      Total  Temperature
# 0       519.15    1688.88   90921.65        28.57
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     129 non-null    object
#  1   Electricity_Requirement  129 non-null    float64
#  2   Humidity                 129 non-null    float64
#  3   Rainfall                 129 non-null    float64
#  4   Solar_Irradiance         129 non-null    float64
#  5   Coal                     129 non-null    float64
#  6   Oil & Gas                129 non-null    float64
#  7   Nuclear                  129 non-null    float64
#  8   Hydro                    129 non-null    float64
#  9   Solar                    129 non-null    float64
#  10  Wind                     129 non-null    float64
#  11  Small-Hydro              129 non-null    float64
#  12  Bio Power                129 non-null    float64
# ...

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    format="%d-%m-%Y"
)

# %%
# extracting year and month
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
