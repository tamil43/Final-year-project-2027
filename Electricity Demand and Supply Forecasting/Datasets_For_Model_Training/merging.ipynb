# %%
import pandas as pd
from functools import reduce

# Read all CSV files
electricity = pd.read_csv("Electricity Requirement.csv")
humidity = pd.read_csv("Humidity Datasets.csv")
rainfall = pd.read_csv("Rainfall datasets.csv")
solar = pd.read_csv("solar_irradiance.csv")
temperature = pd.read_csv("Temperature Dataset.csv")

# Convert Date column to datetime
datasets = [
    electricity,
    humidity,
    rainfall,
    solar,
    temperature
]

for df in datasets:
    df["Date"] = pd.to_datetime(df["Date"])

# Merge all datasets on Date
merged_df = reduce(
    lambda left, right: pd.merge(
        left,
        right,
        on="Date",
        how="inner"
    ),
    datasets
)

# Sort by Date
merged_df = merged_df.sort_values("Date").reset_index(drop=True)

# Save merged dataset
merged_df.to_csv("Final_Merged_Dataset.csv", index=False)
merged_df.head(15)
# Out:
#         Date  Electricity_Requirement  Humidity    Rainfall  Solar_Irradiance  \
# 0 2016-01-01                   8151.0     78.24    2.164286        162.750000
# 1 2017-01-01                   8286.6     66.75   41.844286        151.660000
# 2 2018-01-01                   8620.9     72.98    7.354857        162.380000
# 3 2019-01-01                   8681.0     67.84    0.786286        136.780000
# 4 2020-01-01                   8544.0     76.99    9.249714        158.500000
# 5 2021-01-01                   7886.0     85.87  237.878000        139.220000
# 6 2022-01-01                   8873.0     81.80   40.069429        157.910000
# 7 2023-01-01                   9230.0     74.83   12.746857        152.220000
# 8 2024-01-01                   9658.0     80.30   37.970286        140.880000
# 9 2025-01-01                   9795.0     80.46   31.285429        268.909644
#
#    Temperature
# 0        23.84
# 1        25.03
# 2        24.18
# 3        24.33
# 4        24.82
# 5        23.96
# 6        24.49
# 7        23.66
# 8        24.62
# 9        23.86

# %%
print(electricity.shape)
print(humidity.shape)
print(rainfall.shape)
print(solar.shape)
print(supply.shape)
print(temperature.shape)
# Out:
# (134, 2)
# (132, 2)
# (132, 2)
# (132, 2)
# (129, 10)
# (132, 2)

# %%
print(electricity["Date"].dtype)
print(humidity["Date"].dtype)
print(rainfall["Date"].dtype)
print(solar["Date"].dtype)
print(supply["Date"].dtype)
print(temperature["Date"].dtype)
# Out:
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]
# datetime64[ns]

# %%
print(electricity["Date"].nunique())
print(humidity["Date"].nunique())
print(rainfall["Date"].nunique())
print(solar["Date"].nunique())
print(supply["Date"].nunique())
print(temperature["Date"].nunique())
# Out:
# 134
# 132
# 132
# 132
# 129
# 132

# %%
print("Electricity")
print(electricity["Date"].sort_values().head(15))
print(electricity["Date"].sort_values().tail(15))

print("\nSupply")
print(supply["Date"].sort_values().head(15))
print(supply["Date"].sort_values().tail(15))
# Out:
# Electricity
# 0    2015-04-01
# 1    2015-05-01
# 2    2015-06-01
# 3    2015-07-01
# 4    2015-08-01
# 5    2015-09-01
# 6    2015-10-01
# 7    2015-11-01
# 8    2015-12-01
# 9    2016-01-01
# 10   2016-02-01
# 11   2016-03-01
# 12   2016-04-01
# 13   2016-05-01
# 14   2016-06-01
# Name: Date, dtype: datetime64[ns]
# 119   2025-03-01
# 120   2025-04-01
# 121   2025-05-01
# 122   2025-06-01
# 123   2025-07-01
# 124   2025-08-01
# 125   2025-09-01
# 126   2025-10-01
# 127   2025-11-01
# 128   2025-12-01
# 129   2026-01-01
# 130   2026-02-01
# 131   2026-03-01
# 132   2026-04-01
# 133   2026-05-01
# Name: Date, dtype: datetime64[ns]
#
# Supply
# 0    2015-04-01
# 1    2015-05-01
# 2    2015-06-01
# 3    2015-07-01
# 4    2015-08-01
# 5    2015-09-01
# 6    2015-10-01
# 7    2015-11-01
# 8    2015-12-01
# 9    2016-01-01
# 10   2016-02-01
# 11   2016-03-01
# 12   2016-04-01
# 13   2016-05-01
# 14   2016-06-01
# Name: Date, dtype: datetime64[ns]
# 114   2024-10-01
# 115   2024-11-01
# 116   2024-12-01
# 117   2025-01-01
# 118   2025-02-01
# 119   2025-03-01
# 120   2025-04-01
# 121   2025-05-01
# 122   2025-06-01
# 123   2025-07-01
# 124   2025-08-01
# 125   2025-09-01
# 126   2025-10-01
# 127   2025-11-01
# 128   2025-12-01
# Name: Date, dtype: datetime64[ns]

# %%
print(supply["Date"].head(20))
print(supply["Date"].tail(20))
# Out:
# 0    2015-04-01
# 1    2015-05-01
# 2    2015-06-01
# 3    2015-07-01
# 4    2015-08-01
# 5    2015-09-01
# 6    2015-10-01
# 7    2015-11-01
# 8    2015-12-01
# 9    2016-01-01
# 10   2016-02-01
# 11   2016-03-01
# 12   2016-04-01
# 13   2016-05-01
# 14   2016-06-01
# 15   2016-07-01
# 16   2016-08-01
# 17   2016-09-01
# 18   2016-10-01
# 19   2016-11-01
# Name: Date, dtype: datetime64[ns]
# 109   2024-05-01
# 110   2024-06-01
# 111   2024-07-01
# 112   2024-08-01
# 113   2024-09-01
# 114   2024-10-01
# 115   2024-11-01
# 116   2024-12-01
# 117   2025-01-01
# 118   2025-02-01
# 119   2025-03-01
# 120   2025-04-01
# 121   2025-05-01
# 122   2025-06-01
# 123   2025-07-01
# 124   2025-08-01
# 125   2025-09-01
# 126   2025-10-01
# 127   2025-11-01
# 128   2025-12-01
# Name: Date, dtype: datetime64[ns]

# %%
print(solar["Date"].head(20))
print(solar["Date"].tail(20))
# Out:
# 0    2015-01-01
# 1    2015-01-02
# 2    2015-01-03
# 3    2015-01-04
# 4    2015-01-05
# 5    2015-01-06
# 6    2015-01-07
# 7    2015-01-08
# 8    2015-01-09
# 9    2015-01-10
# 10   2015-01-11
# 11   2015-01-12
# 12   2016-01-01
# 13   2016-01-02
# 14   2016-01-03
# 15   2016-01-04
# 16   2016-01-05
# 17   2016-01-06
# 18   2016-01-07
# 19   2016-01-08
# Name: Date, dtype: datetime64[ns]
# 112   2024-01-05
# 113   2024-01-06
# 114   2024-01-07
# 115   2024-01-08
# 116   2024-01-09
# 117   2024-01-10
# 118   2024-01-11
# 119   2024-01-12
# 120   2025-01-01
# 121   2025-01-02
# 122   2025-01-03
# 123   2025-01-04
# 124   2025-01-05
# 125   2025-01-06
# 126   2025-01-07
# 127   2025-01-08
# 128   2025-01-09
# 129   2025-01-10
# 130   2025-01-11
# 131   2025-01-12
# Name: Date, dtype: datetime64[ns]

# %%
print(electricity.columns)
print(supply.columns)
# Out:
# Index(['Date', 'Electricity_Requirement'], dtype='object')
# Index(['Date', 'Coal - Generation (in MU)', 'Oil & Gas - Generation (in MU)',
#        'Nuclear - Generation (in MU)', 'Hydro - Generation (in MU)',
#        'Solar - Generation (in MU)', 'Wind - Generation (in MU)',
#        'Small-Hydro - Generation (in MU)', 'Bio Power - Generation (in MU)',
#        'Total'],
#       dtype='object')
