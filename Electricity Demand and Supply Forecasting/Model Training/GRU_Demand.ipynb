# %%
# ==========================================================
# CELL 1 : Import Required Libraries
# ==========================================================

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    r2_score
)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# ==========================================================
# Set Random Seed for Reproducibility
# ==========================================================

import random
import tensorflow as tf

SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("Random Seed Fixed Successfully!")
# Out:
# Random Seed Fixed Successfully!

# %%
# ============================
# Load Preprocessed Dataset
# ============================

import joblib

X_train = joblib.load("Demand_X_train.pkl")
X_test = joblib.load("Demand_X_test.pkl")

y_train = joblib.load("Demand_y_train.pkl")
y_test = joblib.load("Demand_y_test.pkl")

print("Training Features Shape :", X_train.shape)
print("Testing Features Shape  :", X_test.shape)

print("\nTraining Target Shape :", y_train.shape)
print("Testing Target Shape  :", y_test.shape)
# Out:
# Training Features Shape : (100, 17)
# Testing Features Shape  : (26, 17)
#
# Training Target Shape : (100,)
# Testing Target Shape  : (26,)

# %%
# ============================
# Feature Scaling
# ============================

from sklearn.preprocessing import MinMaxScaler

# Feature Scaler
X_scaler = MinMaxScaler()

X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Target Scaler
y_scaler = MinMaxScaler()

y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.values.reshape(-1, 1))

print("Feature Scaling Completed Successfully!")
print("X_train_scaled :", X_train_scaled.shape)
print("X_test_scaled  :", X_test_scaled.shape)

print("y_train_scaled :", y_train_scaled.shape)
print("y_test_scaled  :", y_test_scaled.shape)
# Out:
# Feature Scaling Completed Successfully!
# X_train_scaled : (100, 17)
# X_test_scaled  : (26, 17)
# y_train_scaled : (100, 1)
# y_test_scaled  : (26, 1)

# %%
# ============================
# Reshape Data for LSTM
# ============================

X_train_lstm = X_train_scaled.reshape(
    X_train_scaled.shape[0],
    1,
    X_train_scaled.shape[1]
)

X_test_lstm = X_test_scaled.reshape(
    X_test_scaled.shape[0],
    1,
    X_test_scaled.shape[1]
)

print("Training Shape :", X_train_lstm.shape)
print("Testing Shape  :", X_test_lstm.shape)
# Out:
# Training Shape : (100, 1, 17)
# Testing Shape  : (26, 1, 17)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.layers import GRU
from tensorflow.keras.callbacks import EarlyStopping

# %%
# ============================
# Build Baseline GRU Model
# ============================

model = Sequential()

# GRU Layer
model.add(
    GRU(
        units=64,
        activation='tanh',
        input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])
    )
)

# Dropout Layer
model.add(Dropout(0.3))

# Output Layer
model.add(Dense(1))

# Compile Model
optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001
)

model.compile(
    optimizer=optimizer,
    loss='mse'
)

print(model.summary())
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        15,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,001 (62.50 KB)
#  Trainable params: 16,001 (62.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# ============================
# Train LSTM Model
# ============================

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True
)

history = model.fit(
    X_train_lstm,
    y_train_scaled,
    epochs=200,
    batch_size=8,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0714 - val_loss: 0.0406
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0526 - val_loss: 0.0458
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0371 - val_loss: 0.0568
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0207 - val_loss: 0.0328
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0259 - val_loss: 0.0220
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0196 - val_loss: 0.0283
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0144 - val_loss: 0.0294
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0203 - val_loss: 0.0157
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0156 - val_loss: 0.0203
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0187 - val_loss: 0.0210
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0164 - val_loss: 0.0126
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0189 - val_loss: 0.0145
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0133 - val_loss: 0.0159
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0109 - val_loss: 0.0109
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0117 - val_loss: 0.0164
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0147 - val_loss: 0.0118
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0134 - val_loss: 0.0133
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0112 - val_loss: 0.0120
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0106 - val_loss: 0.0082
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0102 - val_loss: 0.0139
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0112 - val_loss: 0.0142
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0097 - val_loss: 0.0096
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0107 - val_loss: 0.0088
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0094 - val_loss: 0.0062
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0133 - val_loss: 0.0099
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0075 - val_loss: 0.0125
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0089 - val_loss: 0.0068
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0112 - val_loss: 0.0147
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0082 - val_loss: 0.0051
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0094 - val_loss: 0.0065
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0076 - val_loss: 0.0062
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0088 - val_loss: 0.0038
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0084 - val_loss: 0.0052
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0079 - val_loss: 0.0036
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0065 - val_loss: 0.0043
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0072 - val_loss: 0.0036
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - val_loss: 0.0039
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0075 - val_loss: 0.0045
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0077 - val_loss: 0.0049
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0097 - val_loss: 0.0047
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0070 - val_loss: 0.0043
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0068 - val_loss: 0.0040
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0068 - val_loss: 0.0036
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0078 - val_loss: 0.0050
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0079 - val_loss: 0.0046
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0075 - val_loss: 0.0041
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0074 - val_loss: 0.0048
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0074 - val_loss: 0.0043
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0058 - val_loss: 0.0038
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0065 - val_loss: 0.0041
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0065 - val_loss: 0.0043
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0054 - val_loss: 0.0043
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0076 - val_loss: 0.0037
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0066 - val_loss: 0.0035
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068 - val_loss: 0.0037
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0082 - val_loss: 0.0037
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0067 - val_loss: 0.0036
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0079 - val_loss: 0.0044
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0069 - val_loss: 0.0036
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0057 - val_loss: 0.0044
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0054 - val_loss: 0.0042
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0077 - val_loss: 0.0034
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0060 - val_loss: 0.0039
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0063 - val_loss: 0.0033
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0061 - val_loss: 0.0037
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0057 - val_loss: 0.0042
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0070 - val_loss: 0.0039
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0063 - val_loss: 0.0034
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0063 - val_loss: 0.0035
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0062 - val_loss: 0.0035
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055 - val_loss: 0.0033
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0053 - val_loss: 0.0041
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0055 - val_loss: 0.0035
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0059 - val_loss: 0.0039
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0075 - val_loss: 0.0033
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0062 - val_loss: 0.0043
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0056 - val_loss: 0.0035
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0078 - val_loss: 0.0033
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0054 - val_loss: 0.0044
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0062 - val_loss: 0.0036
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0059 - val_loss: 0.0051
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0059 - val_loss: 0.0034
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0069 - val_loss: 0.0034
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0056 - val_loss: 0.0035
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0054 - val_loss: 0.0034
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0051 - val_loss: 0.0040
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0064 - val_loss: 0.0038
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 105/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0060 - val_loss: 0.0044

# %%
# ============================
# Make Predictions
# ============================

# Training Predictions
train_predictions = model.predict(X_train_lstm)

# Testing Predictions
test_predictions = model.predict(X_test_lstm)

# Convert predictions back to original scale
train_predictions = y_scaler.inverse_transform(train_predictions)
test_predictions = y_scaler.inverse_transform(test_predictions)

# Convert actual values back to original scale
y_train_actual = y_scaler.inverse_transform(y_train_scaled)
y_test_actual = y_scaler.inverse_transform(y_test_scaled)

print("Prediction Completed Successfully!")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Prediction Completed Successfully!

# %%
# ============================
# Model Evaluation
# ============================

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    mean_absolute_percentage_error,
    r2_score
)

import numpy as np

# -----------------------------
# Training Metrics
# -----------------------------
train_mae = mean_absolute_error(y_train_actual, train_predictions)
train_rmse = np.sqrt(mean_squared_error(y_train_actual, train_predictions))
train_mape = mean_absolute_percentage_error(y_train_actual, train_predictions) * 100
train_r2 = r2_score(y_train_actual, train_predictions)

print("=" * 50)
print("Training Performance")
print("=" * 50)
print(f"MAE  : {train_mae:.2f}")
print(f"RMSE : {train_rmse:.2f}")
print(f"MAPE : {train_mape:.2f}%")
print(f"R²   : {train_r2:.4f}")

# -----------------------------
# Testing Metrics
# -----------------------------
test_mae = mean_absolute_error(y_test_actual, test_predictions)
test_rmse = np.sqrt(mean_squared_error(y_test_actual, test_predictions))
test_mape = mean_absolute_percentage_error(y_test_actual, test_predictions) * 100
test_r2 = r2_score(y_test_actual, test_predictions)

print("\n")
print("=" * 50)
print("Testing Performance")
print("=" * 50)
print(f"MAE  : {test_mae:.2f}")
print(f"RMSE : {test_rmse:.2f}")
print(f"MAPE : {test_mape:.2f}%")
print(f"R²   : {test_r2:.4f}")
# Out:
# ==================================================
# Training Performance
# ==================================================
# MAE  : 202.41
# RMSE : 273.18
# MAPE : 2.27%
# R²   : 0.9151
#
#
# ==================================================
# Testing Performance
# ==================================================
# MAE  : 290.12
# RMSE : 391.34
# MAPE : 2.75%
# R²   : 0.8416
